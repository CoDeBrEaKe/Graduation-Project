# %%
import cv2
import pytesseract
import pyttsx3
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
def click_event(event, xPos, yPos, flags, params):
    
     if event == cv2.EVENT_LBUTTONDOWN:
         boxes = pytesseract.image_to_data(img)
         for x, y in enumerate(boxes.splitlines()):
             if x != 0:
                 y = y.split()
                 if len(y) == 12:
                     x_axis, y_axis, w, h = int(y[6]), int(y[7]), int(y[8]), int(y[9])
                     if xPos >= x_axis and xPos <= x_axis + w:
                         if yPos >= y_axis and yPos <= y_axis + h:
                             the_word = y[11]
                             engine = pyttsx3.init()
                             voices = engine.getProperty('voices')
                             engine.setProperty('voice', voices[1].id)
                             engine.say(the_word)
                             engine.runAndWait()
                             print(the_word)

                             cv2.rectangle(img, (x_axis, y_axis), (w + x_axis, h + y_axis), (0, 255, 0), 3)
                             cv2.imshow("Image", img)
                             cv2.waitKey(50)


cap=cv2.VideoCapture("https://192.168.1.11:8080/video")

while(cap.isOpened()):
     ret,img=cap.read()
     if ret :
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
        #img=img[0:240,0:360]

        cv2.imshow('Image',img)

        cv2.setMouseCallback('Image',click_event)
        #print(img.shape)
        if cv2.waitKey(1)==ord('q'):
             break
     else:
         break

cap.release()
cv2.destroyAllWindows()
# Out:
# history
# ue
# There
# refining
# systematically
# best
# disciplines
# with
# with
# other
# Potted
# of
# history
# AL—Pasth
# AL—Pasth
# Neural
# AL—Pasth
# network’
# AL—Pasth
# AL—Pasth

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.11.0
#   Downloading tensorflow_intel-2.11.0-cp39-cp39-win_amd64.whl (266.3 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.1.1)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Using cached tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Collecting tensorboard<2.12,>=2.11
#   Using cached tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.21)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-win_amd64.whl (23.2 MB)
# Requirement already satisfied: packaging in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Collecting keras<2.12,>=2.11.0
#   Using cached keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.42.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: setuptools in c:\users\electronica care\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (61.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\electronica care\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\electronica care\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.33.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\electronica care\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\electronica care\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\electronica care\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\electronica care\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\electronica care\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\electronica care\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\electronica care\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\electronica care\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.10)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\electronica care\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.4)
# Installing collected packages: oauthlib, requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras, google-pasta, gast, astunparse, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 keras-2.11.0 libclang-15.0.6.1 oauthlib-3.2.2 opt-einsum-3.3.0 requests-oauthlib-1.3.1 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-intel-2.11.0 tensorflow-io-gcs-filesystem-0.30.0 termcolor-2.2.0

# %%
import time
import os
import cv2
import numpy as np
import pytesseract
import pyttsx3 as pyttsx3
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'


cap = cv2.VideoCapture("http://192.168.1.11:8080/video")
while True:
    # Capture each frame from the video feed
    extra, frame = cap.read()
    boxes = pytesseract.image_to_data(frame)
    print(boxes)
    for x, y in enumerate(boxes.splitlines()):
        if x != 0:
            y = y.split()
            if len(y) == 12:
                x_axis, y_axis, w, h = int(y[6]), int(y[7]), int(y[8]), int(y[9])
                the_word = y[11]
                engine = pyttsx3.init()
                voices = engine.getProperty('voices')
                engine.setProperty('voice', voices[1].id)
                engine.say(the_word)
                engine.runAndWait()
                print(the_word)
    cv2.imshow('video capture' , frame)
    cv2.waitKey(10)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	960	540	-1
# 2	1	1	0	0	0	0	140	960	400	-1
# 3	1	1	1	0	0	0	140	960	400	-1
# 4	1	1	1	1	0	0	140	960	400	-1
# 5	1	1	1	1	1	0	140	960	400	95.000000
#
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	960	540	-1
# 2	1	1	0	0	0	0	0	298	284	-1
# 3	1	1	1	0	0	0	0	298	284	-1
# 4	1	1	1	1	0	0	0	298	284	-1
# 5	1	1	1	1	1	0	0	298	284	95.000000
#
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	960	540	-1
# 2	1	1	0	0	0	0	0	392	472	-1
# 3	1	1	1	0	0	0	0	392	472	-1
# 4	1	1	1	1	0	0	0	392	472	-1
# 5	1	1	1	1	1	0	0	392	472	95.000000
#
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	960	540	-1
# 2	1	1	0	0	0	0	0	440	522	-1
# 3	1	1	1	0	0	0	0	440	522	-1
# 4	1	1	1	1	0	0	0	440	522	-1
# 5	1	1	1	1	1	0	0	440	522	95.000000
#
# level	page_num	block_num	par_num	line_num	word_num	left	top	width	height	conf	text
# 1	1	0	0	0	0	0	0	960	540	-1
# 2	1	1	0	0	0	0	0	396	480	-1
# 3	1	1	1	0	0	0	0	396	480	-1
# 4	1	1	1	1	0	0	0	396	480	-1
# 5	1	1	1	1	1	0	0	396	480	95.000000
#
# 4	1	4	1	3	0	474	417	219	23	-1
# 5	1	4	1	3	1	474	429	41	11	87.922356	sulting
# 5	1	4	1	3	2	520	431	3	4	66.268982	©
# 5	1	4	1	3	3	528	422	54	12	18.778702	utbacks
# 5	1	4	1	3	4	587	423	12	7	75.403931	in,
# 5	1	4	1	3	5	604	417	89	13	11.158028	enthusiasnys
# 4	1	4	1	4	0	623	435	61	11	-1
# 5	1	4	1	4	1	623	437	10	9	76.369148	Jes
# 5	1	4	1	4	2	643	437	11	7	77.804642	of
# 5	1	4	1	4	3	659	435	25	8	23.238380	intts
# 4	1	4	1	5	0	639	450	52	11	-1
# 5	1	4	1	5	1	639	451	10	10	55.303375	pest
# 5	1	4	1	5	2	661	450	30	7	62.187424	one
# 4	1	4	1	6	0	626	464	142	24	-1
# 5	1	4	1	6	1	626	471	48	17	74.100555	yapidly
# 5	1	4	1	6	2	682	467	41	13	0.000000	inthe
# 5	1	4	1	6	3	729	464	39	16	78.996964	pasts
# 4	1	4	1	7	0	658	485	97	21	-1
# 5	1	4	1	7	1	658	485	97	21	0.000000	perimenting
# 2	1	5	0	0	0	694	407	83	15	-1
# 3	1	5	1	0	0	694	407	83	15	-1
# 4	1	5	1	1	0	694	407	83	15	-1
# 5	1	5	1	1	1	694	416	4	6	86.551880	and
# 5	1	5	1	1	2	708	407	69	13	0.000000	fUNSIN,
# 2	1	6	0	0	0	459	479	161	19	-1
# 3	1	6	1	0	0	459	479	161	19	-1
# 4	1	6	1	1	0	459	479	161	19	-1
# 5	1	6	1	1	1	459	488	12	10	67.887070	Al
# 5	1	6	1	1	2	478	488	23	9	37.697845	has
# 5	1	6	1	1	3	506	479	71	17	37.697845	advanced
# 5	1	6	1	1	4	583	480	37	10	88.980591	more
# 2	1	7	0	0	0	459	495	189	24	-1
# 3	1	7	1	0	0	459	495	189	24	-1
# 4	1	7	1	1	0	459	495	189	24	-1
# 5	1	7	1	1	1	459	507	23	12	96.690498	the
# 5	1	7	1	1	2	488	500	62	16	51.002979	scientific
# 5	1	7	1	1	3	559	495	58	17	96.399971	method
# 5	1	7	1	1	4	623	496	25	10	51.079147	ine
# 2	1	8	0	0	0	354	175	606	365	-1
# 3	1	8	1	0	0	354	175	606	365	-1
# 4	1	8	1	1	0	354	175	606	365	-1
# 5	1	8	1	1	1	354	175	606	365	95.000000
# 2	1	9	0	0	0	627	509	124	26	-1
# 3	1	9	1	0	0	627	509	124	26	-1
# 4	1	9	1	1	0	627	509	124	26	-1
# 5	1	9	1	1	1	627	513	69	22	36.005131	derstanding
#
# alintelige
# nc’
# jistory
# of
# artifici
# het
# t
# y
# OF
# Al
# has
# had
# cycle
# sulting
# ©
# utbacks
# in,
# enthusiasnys
# Jes
# of
# intts
# pest
# one
# yapidly
# inthe
# pasts
# perimenting
# and
# fUNSIN,
# Al
# has
